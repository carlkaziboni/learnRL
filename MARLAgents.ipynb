# %%
# %cd ml-agents
# %pip install -e ./ml-agents-envs
# %pip install -e ./ml-agents
# Out:
# /Users/carlkaziboni/Documents/HuggingFaceRL/ml-agents
# Obtaining file:///Users/carlkaziboni/Documents/HuggingFaceRL/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# ...
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 7.7 MB/s eta 0:00:0000:01:00:01
# ...

# %%
# %conda install grpcio
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/carlkaziboni/anaconda3/envs/mlagentsrl
#
#   added / updated specs:
#     - grpcio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     grpcio-1.71.0              |  py310h313beb8_0         1.1 MB
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   c-ares             pkgs/main/osx-arm64::c-ares-1.19.1-h80987f9_0
#   grpcio             pkgs/main/osx-arm64::grpcio-1.71.0-py310h313beb8_0
#   libabseil          pkgs/main/osx-arm64::libabseil-20250127.0-cxx17_h313beb8_0
#   libgrpc            pkgs/main/osx-arm64::libgrpc-1.71.0-h62f6fdd_0
# ...

# %%
# !mlagents-learn ./ml-agents/config/poca/SoccerTwos.yaml --env=./ml-agents/training-envs-executables/SoccerTwos/SoccerTwos.app --run-id="SoccerTwos" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.2.0.dev0,
#   ml-agents-envs: 1.2.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.7.1
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# ...

# %%
# !mlagents-push-to-hf  --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="carlkaziboni/poca-SoccerTwos" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SoccerTwos to the Hugging Face Hub
# SoccerTwos-4499980.onnx:   0%|                      | 0.00/1.77M [00:00<?, ?B/s]
# SoccerTwos-3499974.onnx:   0%|                      | 0.00/1.77M [00:00<?, ?B/s]
#
# SoccerTwos-3999941.pt:   0%|                        | 0.00/28.4M [00:00<?, ?B/s]
#
#
# SoccerTwos-3499974.pt:   0%|                        | 0.00/28.4M [00:00<?, ?B/s]
#
#
#
# SoccerTwos-3999941.onnx:   0%|                      | 0.00/1.77M [00:00<?, ?B/s]
#
#
#
#
# SoccerTwos-4499980.onnx:   1%|▏             | 16.4k/1.77M [00:00<00:11, 146kB/s]
#
# SoccerTwos-3999941.pt:   0%|                | 16.4k/28.4M [00:00<03:11, 148kB/s]
# SoccerTwos-3499974.onnx:   1%|▏             | 16.4k/1.77M [00:00<00:11, 147kB/s]
#
#
#
# ...
