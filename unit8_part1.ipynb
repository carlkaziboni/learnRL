# %% [markdown]
# # Unit 8: Proximal Policy Gradient (PPO) with PyTorch 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/thumbnail.png" alt="Unit 8"/>
#
#
# In this notebook, you'll learn to **code your PPO agent from scratch with PyTorch using CleanRL implementation as model**.
#
# To test its robustness, we're going to train it in:
#
# - [LunarLander-v2 🚀](https://www.gymlibrary.dev/environments/box2d/lunar_lander/)

# %% [markdown]
# ⬇️ Here is an example of what you will achieve. ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/ppo-LunarLander-v2/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to **code your PPO agent from scratch using PyTorch**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [PPO by reading Unit 8](https://huggingface.co/deep-rl-course/unit8/introduction) 🤗

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process), you need to push one model, we don't ask for a minimal result but we **advise you to try different hyperparameters settings to get better results**.
#
# If you don't find your model, **go to the bottom of the page and click on the refresh button**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %pip install setuptools==65.5.0
# Out:
# Requirement already satisfied: setuptools==65.5.0 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (65.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !apt install swig cmake
# %pip install pyglet==1.5
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Virtual display
#       2 from pyvirtualdisplay import Display
# ----> 4 virtual_display = Display(visible=0, size=(1400, 900))
#       5 virtual_display.start()
#
# File ~/anaconda3/envs/unit8/lib/python3.9/site-packages/pyvirtualdisplay/display.py:54, in Display.__init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      51 if not cls:
#      52     raise ValueError("unknown backend: %s" % self._backend)
# ---> 54 self._obj = cls(
#      55     size=size,
#      56     color_depth=color_depth,
#      57     bgcolor=bgcolor,
#      58     retries=retries,
#      59     use_xauth=use_xauth,
#      60     # check_startup=check_startup,
#      61     extra_args=extra_args,
#      62     manage_global_env=manage_global_env,
#      63     **kwargs
#      64 )
#
# File ~/anaconda3/envs/unit8/lib/python3.9/site-packages/pyvirtualdisplay/xvfb.py:44, in XvfbDisplay.__init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, retries, extra_args, manage_global_env)
#      41 self._fbdir = fbdir
#      42 self._dpi = dpi
# ---> 44 AbstractDisplay.__init__(
#      45     self,
#      46     PROGRAM,
#      47     use_xauth=use_xauth,
#      48     retries=retries,
#      49     extra_args=extra_args,
#      50     manage_global_env=manage_global_env,
#      51 )
#
# File ~/anaconda3/envs/unit8/lib/python3.9/site-packages/pyvirtualdisplay/abstractdisplay.py:85, in AbstractDisplay.__init__(self, program, use_xauth, retries, extra_args, manage_global_env)
#      82 self._pipe_wfd = None
#      83 self._retries_current = 0
# ---> 85 helptext = get_helptext(program)
#      86 self._has_displayfd = "-displayfd" in helptext
#      87 if not self._has_displayfd:
#
# File ~/anaconda3/envs/unit8/lib/python3.9/site-packages/pyvirtualdisplay/util.py:13, in get_helptext(program)
#       6 cmd = [program, "-help"]
#       8 # py3.7+
#       9 # p = subprocess.run(cmd, capture_output=True)
#      10 # stderr = p.stderr
#      11
#      12 # py3.6 also
# ---> 13 p = subprocess.Popen(
#      14     cmd,
#      15     stdout=subprocess.PIPE,
#      16     stderr=subprocess.PIPE,
#      17     shell=False,
#      18 )
#      19 _, stderr = p.communicate()
#      21 helptext = stderr.decode("utf-8", "ignore")
#
# File ~/anaconda3/envs/unit8/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/envs/unit8/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Xvfb'

# %% [markdown]
# ## Install dependencies 🔽
# For this exercise, we use `gym==0.22`.

# %%
# %pip install gym==0.22
# %pip install imageio-ffmpeg
# %pip install huggingface_hub
# %pip install gym[box2d]==0.22
# Out:
# Requirement already satisfied: gym==0.22 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from gym==0.22) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from gym==0.22) (3.1.1)
# Requirement already satisfied: importlib_metadata>=4.10.0 in /Users/carlkaziboni/.local/lib/python3.9/site-packages (from gym==0.22) (8.7.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from gym==0.22) (0.0.8)
# Requirement already satisfied: zipp>=3.20 in /Users/carlkaziboni/.local/lib/python3.9/site-packages (from importlib_metadata>=4.10.0->gym==0.22) (3.22.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imageio-ffmpeg in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (0.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: huggingface_hub in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (0.33.0)
# Requirement already satisfied: filelock in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /Users/carlkaziboni/.local/lib/python3.9/site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/carlkaziboni/.local/lib/python3.9/site-packages (from huggingface_hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from requests->huggingface_hub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlkaziboni/anaconda3/envs/unit8/lib/python3.9/site-packages (from requests->huggingface_hub) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: gym[box2d]==0.22
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Let's code PPO from scratch with Costa Huang tutorial
# - For the core implementation of PPO we're going to use the excellent [Costa Huang](https://costa.sh/) tutorial.
# - In addition to the tutorial, to go deeper you can read the 37 core implementation details: https://iclr-blog-track.github.io/2022/03/25/ppo-implementation-details/
#
# 👉 The video tutorial: https://youtu.be/MEt6rrxH8W4

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/MEt6rrxH8W4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# /Users/carlkaziboni/.local/lib/python3.9/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/MEt6rrxH8W4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# - The best is to code first on the cell below, this way, if you kill the machine **you don't loose the implementation**.

# %%
import argparse
import os
import time
import random
import gym.spaces
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from distutils.util import strtobool
from torch.utils.tensorboard import SummaryWriter
import gym

def parse_args():
    parser = argparse.ArgumentParser()

    try:
        default_exp_name = os.path.basename(__file__).rstrip(".py")
    except NameError:
        default_exp_name = "notebook"

    parser.add_argument("--exp-name", type=str, default=default_exp_name, help="the name of this experiment")
    parser.add_argument("--gym-id", type=str, default="CartPole-v1", help="the id of the gym environment")
    parser.add_argument("--learning-rate", type=float, default=2.5e-4, help="the learning rate of the optimizer")
    parser.add_argument("--seed", type=int, default=1, help="seed of the experiment")
    parser.add_argument("--total-timesteps", type=int, default=25000, help="total timesteps of the experiment")
    parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=True, help="torch.backends.cudnn.deterministic")
    parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, help="enable cuda if available")
    parser.add_argument("--track", type=lambda x:bool(strtobool(x)), default=False, nargs="?", const=True, help="if toggled, this experiment will be tracked with weights and biases")
    parser.add_argument("--wandb-project-name", type=str, default="cleanRL", help="the wandb's project name")
    parser.add_argument("--wandb-entity", type=str, default=None, help="the entity (team) of wandb's project")
    parser.add_argument("--capture-video", type=lambda x:bool(strtobool(x)), default=False, nargs='?', const=True, help="whether to capture videos")
    parser.add_argument("--num-envs", type=int, default=4, help="number of sub environments")
    parser.add_argument("--num-steps", type=int, default=128, help="number of steps to run in each environment per update")
    parser.add_argument("--anneal-lr", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True, help="whether to anneal the learning rate")
    parser.add_argument("--gae", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True, help="whether to use generalized advantage estimation")
    parser.add_argument("--gamma", type=float, default=0.99, help="the discount factor")
    parser.add_argument("--gae-lambda", type=float, default=0.95, help="the lambda parameter for generalized advantage estimation")
    parser.add_argument("--num-minibatches", type=int, default=4, help="number of minibatches")
    parser.add_argument("--update-epochs", type=int, default=4, help="number of epochs to update the model")
    parser.add_argument("--clip-coef", type=float, default=0.2, help="the surrogate clipping coefficient")
    parser.add_argument("--clip-vloss", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True, help="whether to clip the value loss")
    parser.add_argument("--ent-coef", type=float, default=0.01, help="the entropy coefficient")
    parser.add_argument("--vf-coef", type=float, default=0.5, help="the value function coefficient")
    parser.add_argument("--max-grad-norm", type=float, default=0.5, help="the maximum norm for the gradients")
    parser.add_argument("--target-kl", type=float, default=0.015, help="the target KL divergence threshold for early stopping")
    parser.add_argument("--norm-adv", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True, help="whether to normalize advantages")
    parser.add_argument("--repo-id", type=str, default="carlkaziboni/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")

    args, unknown = parser.parse_known_args()
    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    return args

args = parse_args()

run_name = f"{args.gym_id}_{args.exp_name}_{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text("hyperparameters", "|param|value|\n|-|-|\n%s" %
                ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])))
for i in range(100):
    writer.add_scalar("test_loss", i * 2, global_step=i)

random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

def make_env(gym_id, seed, idx, capture_video, run_name):
    def thunk():
        env = gym.make(gym_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        if capture_video:
            if idx == 0:
                env = gym.wrappers.RecordVideo(env, "videos", episode_trigger=lambda t: t % 100 == 0)
            env.seed(seed)
            env.action_space.seed(seed)
            env.observation_space.seed(seed)
        return env
    return thunk

def layer_init(layer, gain=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, gain=gain)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer

class Agent(nn.Module):
    def __init__(self, envs):
        super(Agent, self).__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), gain=1.0)
        )
        self.actor = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, envs.single_action_space.n), gain=0.01)
        )
        
    def get_value(self, x):
        return self.critic(x)
    
    def get_action_and_value(self, x, action=None):
        logits = self.actor(x)
        probs = Categorical(logits=logits)
        if action is None:
            action = probs.sample()
        return action, probs.log_prob(action), probs.entropy(), self.get_value(x)
    

envs = gym.vector.SyncVectorEnv([make_env(args.gym_id, args.seed + i, i, args.capture_video, run_name)
                                 for i in range(args.num_envs)])
assert isinstance(envs.single_action_space, gym.spaces.Discrete)


agent = Agent(envs).to(device)
optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
values = torch.zeros((args.num_steps, args.num_envs)).to(device)

global_step = 0
start_time = time.time()
next_obs = torch.Tensor(envs.reset()).to(device)
next_done = torch.zeros((args.num_envs,)).to(device)
num_updates = args.total_timesteps // args.batch_size

for update in range(1, num_updates + 1):
    if args.anneal_lr:
        frac = 1.0 - (update - 1.0) / num_updates
        lrnow = args.learning_rate * frac
        optimizer.param_groups[0]["lr"] = lrnow

        for step in range(args.num_steps):
            global_step += args.num_envs
            obs[step] = next_obs
            dones[step] = next_done

        with torch.no_grad():
            action, logprob, _, value = agent.get_action_and_value(next_obs)
            values[step] = value.flatten()
        actions[step] = action
        logprobs[step] = logprob

        next_obs, reward, done, info = envs.step(action.cpu().numpy())
        rewards[step] = torch.Tensor(reward).to(device)
        next_obs = torch.Tensor(next_obs).to(device)
        next_done = torch.Tensor(done).to(device)

        for item in info:
            if "episode" in item.keys():
                print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
                writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step=global_step)
                writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step=global_step)
                break

    with torch.no_grad():
        next_value = agent.get_value(next_obs).reshape(1, -1)
        if args.gae:
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values[t + 1]
                delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
            returns = advantages + values
        else:
            returns = torch.zeros_like(rewards).to(device)
            for t in reversed(range(args.num_steps)):
                if t == args.num_steps - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values[t + 1]
                returns[t] = rewards[t] + args.gamma * nextvalues * nextnonterminal
            advantages = returns - values

    b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
    b_logprobs = logprobs.reshape(-1)
    b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
    b_advantages = advantages.reshape(-1)
    b_returns = returns.reshape(-1)
    b_values = values.reshape(-1)
    
    b_inds = np.arange(args.batch_size)
    clipfracs = []

    for epoch in range(args.update_epochs):
        np.random.shuffle(b_inds)
        for start in range(0, args.batch_size, args.minibatch_size):
            end = start + args.minibatch_size
            mb_inds = b_inds[start:end]

            _, newlogprob, entropy, newvalue = agent.get_action_and_value(
                b_obs[mb_inds],
                b_actions.long()[mb_inds]
            )
            logratio = newlogprob - b_logprobs[mb_inds]
            ratio = logratio.exp()

            with torch.no_grad():
                old_approx_kl = (-logratio).mean()
                approx_kl = ((ratio - 1) - logratio).mean()
                clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean()]

            mb_advantages = b_advantages[mb_inds]
            if args.norm_adv:
                mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

            pg_loss1 = -mb_advantages * ratio
            pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
            pg_loss =  torch.max(pg_loss1, pg_loss2).mean()


            newvalue = newvalue.view(-1)
            if args.clip_vloss:
                v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                v_clipped = b_values[mb_inds] + torch.clamp(newvalue - b_values[mb_inds], -args.clip_coef, args.clip_coef)
                v_loss_max = (v_clipped - b_returns[mb_inds]) ** 2
                v_loss = 0.5 * v_loss_max.mean()
            else:
                v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()
            
            entropy_loss = entropy.mean()
            loss = pg_loss - args.ent_coef * entropy_loss + args.vf_coef * v_loss

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
            optimizer.step()
        if args.target_kl is not None:
            if approx_kl > args.target_kl:
                print(f"Early stopping at update {update} due to reaching max kl: {approx_kl:.2f} > {args.target_kl:.2f}")
                break
    
    y_pred = b_values.cpu().detach().numpy()
    y_true = b_returns.cpu().detach().numpy()
    var_y = np.var(y_true)
    explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

    writer.add_scalar("losses/value_loss", v_loss.item(), global_step=global_step)
    writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step=global_step)
    writer.add_scalar("losses/entropy_loss", entropy_loss.item(), global_step=global_step)
    writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step=global_step)
    writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step=global_step)
    writer.add_scalar("losses/explained_variance", explained_var, global_step=global_step)
    writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step=global_step)
    writer.add_scalar("charts/total_num_steps", global_step, global_step=global_step)

envs.close()
writer.close()
# Out:
# Early stopping at update 1 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 2 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 3 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 4 due to reaching max kl: 0.18 > 0.01
# Early stopping at update 5 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 6 due to reaching max kl: 0.18 > 0.01
# Early stopping at update 7 due to reaching max kl: 0.18 > 0.01
# Early stopping at update 8 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 9 due to reaching max kl: 0.20 > 0.01
# Early stopping at update 10 due to reaching max kl: 0.20 > 0.01
# global_step=5632, episodic_return=11.0
# Early stopping at update 11 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 12 due to reaching max kl: 0.20 > 0.01
# Early stopping at update 13 due to reaching max kl: 0.20 > 0.01
# Early stopping at update 14 due to reaching max kl: 0.20 > 0.01
# Early stopping at update 15 due to reaching max kl: 0.18 > 0.01
# Early stopping at update 16 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 17 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 18 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 19 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 20 due to reaching max kl: 0.17 > 0.01
# global_step=10752, episodic_return=21.0
# Early stopping at update 21 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 22 due to reaching max kl: 0.16 > 0.01
# Early stopping at update 23 due to reaching max kl: 0.16 > 0.01
# global_step=12288, episodic_return=13.0
# Early stopping at update 24 due to reaching max kl: 0.15 > 0.01
# Early stopping at update 25 due to reaching max kl: 0.16 > 0.01
# Early stopping at update 26 due to reaching max kl: 0.14 > 0.01
# Early stopping at update 27 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 28 due to reaching max kl: 0.12 > 0.01
# Early stopping at update 29 due to reaching max kl: 0.11 > 0.01
# Early stopping at update 30 due to reaching max kl: 0.11 > 0.01
# Early stopping at update 31 due to reaching max kl: 0.10 > 0.01
# global_step=16384, episodic_return=11.0
# Early stopping at update 32 due to reaching max kl: 0.09 > 0.01
# Early stopping at update 33 due to reaching max kl: 0.11 > 0.01
# Early stopping at update 34 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 35 due to reaching max kl: 0.14 > 0.01
# Early stopping at update 36 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 37 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 38 due to reaching max kl: 0.12 > 0.01
# Early stopping at update 39 due to reaching max kl: 0.15 > 0.01
# global_step=20480, episodic_return=40.0
# Early stopping at update 40 due to reaching max kl: 0.12 > 0.01
# Early stopping at update 41 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 42 due to reaching max kl: 0.15 > 0.01
# global_step=22016, episodic_return=43.0
# Early stopping at update 43 due to reaching max kl: 0.14 > 0.01
# Early stopping at update 44 due to reaching max kl: 0.19 > 0.01
# Early stopping at update 45 due to reaching max kl: 0.15 > 0.01
# Early stopping at update 46 due to reaching max kl: 0.17 > 0.01
# Early stopping at update 47 due to reaching max kl: 0.13 > 0.01
# Early stopping at update 48 due to reaching max kl: 0.16 > 0.01

# %% [markdown]
# ## Add the Hugging Face Integration 🤗
# - In order to push our model to the Hub, we need to define a function `package_to_hub`

# %% [markdown]
# - Add dependencies we need to push our model to the Hub

# %%
from huggingface_hub import HfApi, upload_folder
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio

from wasabi import Printer
msg = Printer()

# %% [markdown]
# - Add new argument in `parse_args()` function to define the repo-id where we want to push the model.

# %%
# Adding HuggingFace argument
parser.add_argument("--repo-id", type=str, default="carlkaziboni/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Adding HuggingFace argument
# ----> 2 parser.add_argument("--repo-id", type=str, default="carlkaziboni/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")
#
# NameError: name 'parser' is not defined

# %% [markdown]
# - Next, we add the methods needed to push the model to the Hub
#
# - These methods will:
#   - `_evalutate_agent()`: evaluate the agent.
#   - `_generate_model_card()`: generate the model card of your agent.
#   - `_record_video()`: record a video of your agent.

# %%
def package_to_hub(repo_id,
                model,
                hyperparameters,
                eval_env,
                video_fps=30,
                commit_message="Push agent to the Hub",
                token= None,
                logs=None
                ):
  """
  Evaluate, Generate a video and Upload a model to Hugging Face Hub.
  This method does the complete pipeline:
  - It evaluates the model
  - It generates the model card
  - It generates a replay video of the agent
  - It pushes everything to the hub
  :param repo_id: id of the model repository from the Hugging Face Hub
  :param model: trained model
  :param eval_env: environment used to evaluate the agent
  :param fps: number of fps for rendering the video
  :param commit_message: commit message
  :param logs: directory on local machine of tensorboard logs you'd like to upload
  """
  msg.info(
        "This function will save, evaluate, generate a video of your agent, "
        "create a model card and push everything to the hub. "
        "It might take up to 1min. \n "
        "This is a work in progress: if you encounter a bug, please open an issue."
    )
  # Step 1: Clone or create the repo
  repo_url = HfApi().create_repo(
        repo_id=repo_id,
        token=token,
        private=False,
        exist_ok=True,
    )

  with tempfile.TemporaryDirectory() as tmpdirname:
    tmpdirname = Path(tmpdirname)

    # Step 2: Save the model
    torch.save(model.state_dict(), tmpdirname / "model.pt")

    # Step 3: Evaluate the model and build JSON
    mean_reward, std_reward = _evaluate_agent(eval_env,
                                           10,
                                           model)

    # First get datetime
    eval_datetime = datetime.datetime.now()
    eval_form_datetime = eval_datetime.isoformat()

    evaluate_data = {
        "env_id": hyperparameters.env_id,
        "mean_reward": mean_reward,
        "std_reward": std_reward,
        "n_evaluation_episodes": 10,
        "eval_datetime": eval_form_datetime,
    }

    # Write a JSON file
    with open(tmpdirname / "results.json", "w") as outfile:
      json.dump(evaluate_data, outfile)

    # Step 4: Generate a video
    video_path =  tmpdirname / "replay.mp4"
    record_video(eval_env, model, video_path, video_fps)

    # Step 5: Generate the model card
    generated_model_card, metadata = _generate_model_card("PPO", hyperparameters.env_id, mean_reward, std_reward, hyperparameters)
    _save_model_card(tmpdirname, generated_model_card, metadata)

    # Step 6: Add logs if needed
    if logs:
      _add_logdir(tmpdirname, Path(logs))

    msg.info(f"Pushing repo {repo_id} to the Hugging Face Hub")

    repo_url = upload_folder(
            repo_id=repo_id,
            folder_path=tmpdirname,
            path_in_repo="",
            commit_message=commit_message,
            token=token,
        )

    msg.info(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
  return repo_url


def _evaluate_agent(env, n_eval_episodes, policy):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param policy: The agent
  """
  episode_rewards = []
  for episode in range(n_eval_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards_ep = 0

    while done is False:
      state = torch.Tensor(state).to(device)
      action, _, _, _ = policy.get_action_and_value(state)
      new_state, reward, done, info = env.step(action.cpu().numpy())
      total_rewards_ep += reward
      if done:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward


def record_video(env, policy, out_directory, fps=30):
  images = []
  done = False
  state = env.reset()
  img = env.render(mode='rgb_array')
  images.append(img)
  while not done:
    state = torch.Tensor(state).to(device)
    # Take the action (index) that have the maximum expected future reward given that state
    action, _, _, _  = policy.get_action_and_value(state)
    state, reward, done, info = env.step(action.cpu().numpy()) # We directly put next_state = state for recording logic
    img = env.render(mode='rgb_array')
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)


def _generate_model_card(model_name, env_id, mean_reward, std_reward, hyperparameters):
  """
  Generate the model card for the Hub
  :param model_name: name of the model
  :env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  :hyperparameters: training arguments
  """
  # Step 1: Select the tags
  metadata = generate_metadata(model_name, env_id, mean_reward, std_reward)

  # Transform the hyperparams namespace to string
  converted_dict = vars(hyperparameters)
  converted_str = str(converted_dict)
  converted_str = converted_str.split(", ")
  converted_str = '\n'.join(converted_str)

  # Step 2: Generate the model card
  model_card = f"""
  # PPO Agent Playing {env_id}

  This is a trained model of a PPO agent playing {env_id}.

  # Hyperparameters
  ```python
  {converted_str}
  ```
  """
  return model_card, metadata


def generate_metadata(model_name, env_id, mean_reward, std_reward):
  """
  Define the tags for the model card
  :param model_name: name of the model
  :param env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  """
  metadata = {}
  metadata["tags"] = [
        env_id,
        "ppo",
        "deep-reinforcement-learning",
        "reinforcement-learning",
        "custom-implementation",
        "deep-rl-course"
  ]

  # Add metrics
  eval = metadata_eval_result(
      model_pretty_name=model_name,
      task_pretty_name="reinforcement-learning",
      task_id="reinforcement-learning",
      metrics_pretty_name="mean_reward",
      metrics_id="mean_reward",
      metrics_value=f"{mean_reward:.2f} +/- {std_reward:.2f}",
      dataset_pretty_name=env_id,
      dataset_id=env_id,
  )

  # Merges both dictionaries
  metadata = {**metadata, **eval}

  return metadata


def _save_model_card(local_path, generated_model_card, metadata):
    """Saves a model card for the repository.
    :param local_path: repository directory
    :param generated_model_card: model card generated by _generate_model_card()
    :param metadata: metadata
    """
    readme_path = local_path / "README.md"
    readme = ""
    if readme_path.exists():
        with readme_path.open("r", encoding="utf8") as f:
            readme = f.read()
    else:
        readme = generated_model_card

    with readme_path.open("w", encoding="utf-8") as f:
        f.write(readme)

    # Save our metrics to Readme metadata
    metadata_save(readme_path, metadata)


def _add_logdir(local_path: Path, logdir: Path):
  """Adds a logdir to the repository.
  :param local_path: repository directory
  :param logdir: logdir directory
  """
  if logdir.exists() and logdir.is_dir():
    # Add the logdir to the repository under new dir called logs
    repo_logdir = local_path / "logs"

    # Delete current logs if they exist
    if repo_logdir.exists():
      shutil.rmtree(repo_logdir)

    # Copy logdir into repo logdir
    shutil.copytree(logdir, repo_logdir)

# %% [markdown]
# - Finally, we call this function at the end of the PPO training

# %%
# Create the evaluation environment
eval_env = gym.make(args.gym_id)

args.env_id = args.gym_id

package_to_hub(
    repo_id=args.repo_id,
    model=agent,
    hyperparameters=args,
    eval_env=eval_env,
    logs=f"runs/{run_name}",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ℹ Pushing repo carlkaziboni/ppo-CartPole-v1 to the Hugging Face Hub
# events.out.tfevents.1751141123.Carls-Air.77078.14:   0%|          | 0.00/28.6k [00:00<?, ?B/s]
# events.out.tfevents.1751141123.Carls-Air.77078.14: 100%|██████████| 28.6k/28.6k [00:00<00:00, 105kB/s]
# model.pt: 100%|██████████| 40.7k/40.7k [00:00<00:00, 126kB/s]
# Upload 2 LFS files: 100%|██████████| 2/2 [00:00<00:00,  2.63it/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/carlkaziboni/ppo-CartPole-v1/tree/main/
# CommitInfo(commit_url='https://huggingface.co/carlkaziboni/ppo-CartPole-v1/commit/cb5cb9cfffaf3101ce2b0f509f93d5198ea5bea3', commit_message='Push agent to the Hub', commit_description='', oid='cb5cb9cfffaf3101ce2b0f509f93d5198ea5bea3', pr_url=None, repo_url=RepoUrl('https://huggingface.co/carlkaziboni/ppo-CartPole-v1', endpoint='https://huggingface.co', repo_type='model', repo_id='carlkaziboni/ppo-CartPole-v1'), pr_revision=None, pr_num=None)

# %% [markdown]
# - Here's what look the ppo.py final file

# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/ppo/#ppopy

import argparse
import os
import random
import time
from distutils.util import strtobool

import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical
from torch.utils.tensorboard import SummaryWriter

from huggingface_hub import HfApi, upload_folder
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import tempfile
import json
import shutil
import imageio

from wasabi import Printer
msg = Printer()

def parse_args():
    # fmt: off
    parser = argparse.ArgumentParser()
    parser.add_argument("--exp-name", type=str, default=os.path.basename(__file__).rstrip(".py"),
        help="the name of this experiment")
    parser.add_argument("--seed", type=int, default=1,
        help="seed of the experiment")
    parser.add_argument("--torch-deterministic", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="if toggled, `torch.backends.cudnn.deterministic=False`")
    parser.add_argument("--cuda", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="if toggled, cuda will be enabled by default")
    parser.add_argument("--track", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="if toggled, this experiment will be tracked with Weights and Biases")
    parser.add_argument("--wandb-project-name", type=str, default="cleanRL",
        help="the wandb's project name")
    parser.add_argument("--wandb-entity", type=str, default=None,
        help="the entity (team) of wandb's project")
    parser.add_argument("--capture-video", type=lambda x: bool(strtobool(x)), default=False, nargs="?", const=True,
        help="weather to capture videos of the agent performances (check out `videos` folder)")

    # Algorithm specific arguments
    parser.add_argument("--env-id", type=str, default="CartPole-v1",
        help="the id of the environment")
    parser.add_argument("--total-timesteps", type=int, default=50000,
        help="total timesteps of the experiments")
    parser.add_argument("--learning-rate", type=float, default=2.5e-4,
        help="the learning rate of the optimizer")
    parser.add_argument("--num-envs", type=int, default=4,
        help="the number of parallel game environments")
    parser.add_argument("--num-steps", type=int, default=128,
        help="the number of steps to run in each environment per policy rollout")
    parser.add_argument("--anneal-lr", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggle learning rate annealing for policy and value networks")
    parser.add_argument("--gae", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Use GAE for advantage computation")
    parser.add_argument("--gamma", type=float, default=0.99,
        help="the discount factor gamma")
    parser.add_argument("--gae-lambda", type=float, default=0.95,
        help="the lambda for the general advantage estimation")
    parser.add_argument("--num-minibatches", type=int, default=4,
        help="the number of mini-batches")
    parser.add_argument("--update-epochs", type=int, default=4,
        help="the K epochs to update the policy")
    parser.add_argument("--norm-adv", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggles advantages normalization")
    parser.add_argument("--clip-coef", type=float, default=0.2,
        help="the surrogate clipping coefficient")
    parser.add_argument("--clip-vloss", type=lambda x: bool(strtobool(x)), default=True, nargs="?", const=True,
        help="Toggles whether or not to use a clipped loss for the value function, as per the paper.")
    parser.add_argument("--ent-coef", type=float, default=0.01,
        help="coefficient of the entropy")
    parser.add_argument("--vf-coef", type=float, default=0.5,
        help="coefficient of the value function")
    parser.add_argument("--max-grad-norm", type=float, default=0.5,
        help="the maximum norm for the gradient clipping")
    parser.add_argument("--target-kl", type=float, default=None,
        help="the target KL divergence threshold")

    # Adding HuggingFace argument
    parser.add_argument("--repo-id", type=str, default="ThomasSimonini/ppo-CartPole-v1", help="id of the model repository from the Hugging Face Hub {username/repo_name}")

    args = parser.parse_args()
    args.batch_size = int(args.num_envs * args.num_steps)
    args.minibatch_size = int(args.batch_size // args.num_minibatches)
    # fmt: on
    return args

def package_to_hub(repo_id,
                model,
                hyperparameters,
                eval_env,
                video_fps=30,
                commit_message="Push agent to the Hub",
                token= None,
                logs=None
                ):
  """
  Evaluate, Generate a video and Upload a model to Hugging Face Hub.
  This method does the complete pipeline:
  - It evaluates the model
  - It generates the model card
  - It generates a replay video of the agent
  - It pushes everything to the hub
  :param repo_id: id of the model repository from the Hugging Face Hub
  :param model: trained model
  :param eval_env: environment used to evaluate the agent
  :param fps: number of fps for rendering the video
  :param commit_message: commit message
  :param logs: directory on local machine of tensorboard logs you'd like to upload
  """
  msg.info(
        "This function will save, evaluate, generate a video of your agent, "
        "create a model card and push everything to the hub. "
        "It might take up to 1min. \n "
        "This is a work in progress: if you encounter a bug, please open an issue."
    )
  # Step 1: Clone or create the repo
  repo_url = HfApi().create_repo(
        repo_id=repo_id,
        token=token,
        private=False,
        exist_ok=True,
    )

  with tempfile.TemporaryDirectory() as tmpdirname:
    tmpdirname = Path(tmpdirname)

    # Step 2: Save the model
    torch.save(model.state_dict(), tmpdirname / "model.pt")

    # Step 3: Evaluate the model and build JSON
    mean_reward, std_reward = _evaluate_agent(eval_env,
                                           10,
                                           model)

    # First get datetime
    eval_datetime = datetime.datetime.now()
    eval_form_datetime = eval_datetime.isoformat()

    evaluate_data = {
        "env_id": hyperparameters.env_id,
        "mean_reward": mean_reward,
        "std_reward": std_reward,
        "n_evaluation_episodes": 10,
        "eval_datetime": eval_form_datetime,
    }

    # Write a JSON file
    with open(tmpdirname / "results.json", "w") as outfile:
      json.dump(evaluate_data, outfile)

    # Step 4: Generate a video
    video_path =  tmpdirname / "replay.mp4"
    record_video(eval_env, model, video_path, video_fps)

    # Step 5: Generate the model card
    generated_model_card, metadata = _generate_model_card("PPO", hyperparameters.env_id, mean_reward, std_reward, hyperparameters)
    _save_model_card(tmpdirname, generated_model_card, metadata)

    # Step 6: Add logs if needed
    if logs:
      _add_logdir(tmpdirname, Path(logs))

    msg.info(f"Pushing repo {repo_id} to the Hugging Face Hub")

    repo_url = upload_folder(
            repo_id=repo_id,
            folder_path=tmpdirname,
            path_in_repo="",
            commit_message=commit_message,
            token=token,
        )

    msg.info(f"Your model is pushed to the Hub. You can view your model here: {repo_url}")
  return repo_url

def _evaluate_agent(env, n_eval_episodes, policy):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param policy: The agent
  """
  episode_rewards = []
  for episode in range(n_eval_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards_ep = 0

    while done is False:
      state = torch.Tensor(state).to(device)
      action, _, _, _ = policy.get_action_and_value(state)
      new_state, reward, done, info = env.step(action.cpu().numpy())
      total_rewards_ep += reward
      if done:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward


def record_video(env, policy, out_directory, fps=30):
  images = []
  done = False
  state = env.reset()
  img = env.render(mode='rgb_array')
  images.append(img)
  while not done:
    state = torch.Tensor(state).to(device)
    # Take the action (index) that have the maximum expected future reward given that state
    action, _, _, _  = policy.get_action_and_value(state)
    state, reward, done, info = env.step(action.cpu().numpy()) # We directly put next_state = state for recording logic
    img = env.render(mode='rgb_array')
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)


def _generate_model_card(model_name, env_id, mean_reward, std_reward, hyperparameters):
  """
  Generate the model card for the Hub
  :param model_name: name of the model
  :env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  :hyperparameters: training arguments
  """
  # Step 1: Select the tags
  metadata = generate_metadata(model_name, env_id, mean_reward, std_reward)

  # Transform the hyperparams namespace to string
  converted_dict = vars(hyperparameters)
  converted_str = str(converted_dict)
  converted_str = converted_str.split(", ")
  converted_str = '\n'.join(converted_str)

  # Step 2: Generate the model card
  model_card = f"""
  # PPO Agent Playing {env_id}

  This is a trained model of a PPO agent playing {env_id}.

  # Hyperparameters
  ```python
  {converted_str}
  ```
  """
  return model_card, metadata

def generate_metadata(model_name, env_id, mean_reward, std_reward):
  """
  Define the tags for the model card
  :param model_name: name of the model
  :param env_id: name of the environment
  :mean_reward: mean reward of the agent
  :std_reward: standard deviation of the mean reward of the agent
  """
  metadata = {}
  metadata["tags"] = [
        env_id,
        "ppo",
        "deep-reinforcement-learning",
        "reinforcement-learning",
        "custom-implementation",
        "deep-rl-course"
  ]

  # Add metrics
  eval = metadata_eval_result(
      model_pretty_name=model_name,
      task_pretty_name="reinforcement-learning",
      task_id="reinforcement-learning",
      metrics_pretty_name="mean_reward",
      metrics_id="mean_reward",
      metrics_value=f"{mean_reward:.2f} +/- {std_reward:.2f}",
      dataset_pretty_name=env_id,
      dataset_id=env_id,
  )

  # Merges both dictionaries
  metadata = {**metadata, **eval}

  return metadata

def _save_model_card(local_path, generated_model_card, metadata):
    """Saves a model card for the repository.
    :param local_path: repository directory
    :param generated_model_card: model card generated by _generate_model_card()
    :param metadata: metadata
    """
    readme_path = local_path / "README.md"
    readme = ""
    if readme_path.exists():
        with readme_path.open("r", encoding="utf8") as f:
            readme = f.read()
    else:
        readme = generated_model_card

    with readme_path.open("w", encoding="utf-8") as f:
        f.write(readme)

    # Save our metrics to Readme metadata
    metadata_save(readme_path, metadata)

def _add_logdir(local_path: Path, logdir: Path):
  """Adds a logdir to the repository.
  :param local_path: repository directory
  :param logdir: logdir directory
  """
  if logdir.exists() and logdir.is_dir():
    # Add the logdir to the repository under new dir called logs
    repo_logdir = local_path / "logs"

    # Delete current logs if they exist
    if repo_logdir.exists():
      shutil.rmtree(repo_logdir)

    # Copy logdir into repo logdir
    shutil.copytree(logdir, repo_logdir)

def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        if capture_video:
            if idx == 0:
                env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        env.seed(seed)
        env.action_space.seed(seed)
        env.observation_space.seed(seed)
        return env

    return thunk


def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer


class Agent(nn.Module):
    def __init__(self, envs):
        super().__init__()
        self.critic = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 1), std=1.0),
        )
        self.actor = nn.Sequential(
            layer_init(nn.Linear(np.array(envs.single_observation_space.shape).prod(), 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, 64)),
            nn.Tanh(),
            layer_init(nn.Linear(64, envs.single_action_space.n), std=0.01),
        )

    def get_value(self, x):
        return self.critic(x)

    def get_action_and_value(self, x, action=None):
        logits = self.actor(x)
        probs = Categorical(logits=logits)
        if action is None:
            action = probs.sample()
        return action, probs.log_prob(action), probs.entropy(), self.critic(x)


if __name__ == "__main__":
    args = parse_args()
    run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
    if args.track:
        import wandb

        wandb.init(
            project=args.wandb_project_name,
            entity=args.wandb_entity,
            sync_tensorboard=True,
            config=vars(args),
            name=run_name,
            monitor_gym=True,
            save_code=True,
        )
    writer = SummaryWriter(f"runs/{run_name}")
    writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
    )

    # TRY NOT TO MODIFY: seeding
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = args.torch_deterministic

    device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

    # env setup
    envs = gym.vector.SyncVectorEnv(
        [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
    )
    assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

    agent = Agent(envs).to(device)
    optimizer = optim.Adam(agent.parameters(), lr=args.learning_rate, eps=1e-5)

    # ALGO Logic: Storage setup
    obs = torch.zeros((args.num_steps, args.num_envs) + envs.single_observation_space.shape).to(device)
    actions = torch.zeros((args.num_steps, args.num_envs) + envs.single_action_space.shape).to(device)
    logprobs = torch.zeros((args.num_steps, args.num_envs)).to(device)
    rewards = torch.zeros((args.num_steps, args.num_envs)).to(device)
    dones = torch.zeros((args.num_steps, args.num_envs)).to(device)
    values = torch.zeros((args.num_steps, args.num_envs)).to(device)

    # TRY NOT TO MODIFY: start the game
    global_step = 0
    start_time = time.time()
    next_obs = torch.Tensor(envs.reset()).to(device)
    next_done = torch.zeros(args.num_envs).to(device)
    num_updates = args.total_timesteps // args.batch_size

    for update in range(1, num_updates + 1):
        # Annealing the rate if instructed to do so.
        if args.anneal_lr:
            frac = 1.0 - (update - 1.0) / num_updates
            lrnow = frac * args.learning_rate
            optimizer.param_groups[0]["lr"] = lrnow

        for step in range(0, args.num_steps):
            global_step += 1 * args.num_envs
            obs[step] = next_obs
            dones[step] = next_done

            # ALGO LOGIC: action logic
            with torch.no_grad():
                action, logprob, _, value = agent.get_action_and_value(next_obs)
                values[step] = value.flatten()
            actions[step] = action
            logprobs[step] = logprob

            # TRY NOT TO MODIFY: execute the game and log data.
            next_obs, reward, done, info = envs.step(action.cpu().numpy())
            rewards[step] = torch.tensor(reward).to(device).view(-1)
            next_obs, next_done = torch.Tensor(next_obs).to(device), torch.Tensor(done).to(device)

            for item in info:
                if "episode" in item.keys():
                    print(f"global_step={global_step}, episodic_return={item['episode']['r']}")
                    writer.add_scalar("charts/episodic_return", item["episode"]["r"], global_step)
                    writer.add_scalar("charts/episodic_length", item["episode"]["l"], global_step)
                    break

        # bootstrap value if not done
        with torch.no_grad():
            next_value = agent.get_value(next_obs).reshape(1, -1)
            if args.gae:
                advantages = torch.zeros_like(rewards).to(device)
                lastgaelam = 0
                for t in reversed(range(args.num_steps)):
                    if t == args.num_steps - 1:
                        nextnonterminal = 1.0 - next_done
                        nextvalues = next_value
                    else:
                        nextnonterminal = 1.0 - dones[t + 1]
                        nextvalues = values[t + 1]
                    delta = rewards[t] + args.gamma * nextvalues * nextnonterminal - values[t]
                    advantages[t] = lastgaelam = delta + args.gamma * args.gae_lambda * nextnonterminal * lastgaelam
                returns = advantages + values
            else:
                returns = torch.zeros_like(rewards).to(device)
                for t in reversed(range(args.num_steps)):
                    if t == args.num_steps - 1:
                        nextnonterminal = 1.0 - next_done
                        next_return = next_value
                    else:
                        nextnonterminal = 1.0 - dones[t + 1]
                        next_return = returns[t + 1]
                    returns[t] = rewards[t] + args.gamma * nextnonterminal * next_return
                advantages = returns - values

        # flatten the batch
        b_obs = obs.reshape((-1,) + envs.single_observation_space.shape)
        b_logprobs = logprobs.reshape(-1)
        b_actions = actions.reshape((-1,) + envs.single_action_space.shape)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)
        b_values = values.reshape(-1)

        # Optimizing the policy and value network
        b_inds = np.arange(args.batch_size)
        clipfracs = []
        for epoch in range(args.update_epochs):
            np.random.shuffle(b_inds)
            for start in range(0, args.batch_size, args.minibatch_size):
                end = start + args.minibatch_size
                mb_inds = b_inds[start:end]

                _, newlogprob, entropy, newvalue = agent.get_action_and_value(b_obs[mb_inds], b_actions.long()[mb_inds])
                logratio = newlogprob - b_logprobs[mb_inds]
                ratio = logratio.exp()

                with torch.no_grad():
                    # calculate approx_kl http://joschu.net/blog/kl-approx.html
                    old_approx_kl = (-logratio).mean()
                    approx_kl = ((ratio - 1) - logratio).mean()
                    clipfracs += [((ratio - 1.0).abs() > args.clip_coef).float().mean().item()]

                mb_advantages = b_advantages[mb_inds]
                if args.norm_adv:
                    mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                # Policy loss
                pg_loss1 = -mb_advantages * ratio
                pg_loss2 = -mb_advantages * torch.clamp(ratio, 1 - args.clip_coef, 1 + args.clip_coef)
                pg_loss = torch.max(pg_loss1, pg_loss2).mean()

                # Value loss
                newvalue = newvalue.view(-1)
                if args.clip_vloss:
                    v_loss_unclipped = (newvalue - b_returns[mb_inds]) ** 2
                    v_clipped = b_values[mb_inds] + torch.clamp(
                        newvalue - b_values[mb_inds],
                        -args.clip_coef,
                        args.clip_coef,
                    )
                    v_loss_clipped = (v_clipped - b_returns[mb_inds]) ** 2
                    v_loss_max = torch.max(v_loss_unclipped, v_loss_clipped)
                    v_loss = 0.5 * v_loss_max.mean()
                else:
                    v_loss = 0.5 * ((newvalue - b_returns[mb_inds]) ** 2).mean()

                entropy_loss = entropy.mean()
                loss = pg_loss - args.ent_coef * entropy_loss + v_loss * args.vf_coef

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(agent.parameters(), args.max_grad_norm)
                optimizer.step()

            if args.target_kl is not None:
                if approx_kl > args.target_kl:
                    break

        y_pred, y_true = b_values.cpu().numpy(), b_returns.cpu().numpy()
        var_y = np.var(y_true)
        explained_var = np.nan if var_y == 0 else 1 - np.var(y_true - y_pred) / var_y

        # TRY NOT TO MODIFY: record rewards for plotting purposes
        writer.add_scalar("charts/learning_rate", optimizer.param_groups[0]["lr"], global_step)
        writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
        writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
        writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
        writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
        writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
        writer.add_scalar("losses/clipfrac", np.mean(clipfracs), global_step)
        writer.add_scalar("losses/explained_variance", explained_var, global_step)
        print("SPS:", int(global_step / (time.time() - start_time)))
        writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

    envs.close()
    writer.close()

    # Create the evaluation environment
    eval_env = gym.make(args.env_id)

    package_to_hub(repo_id = args.repo_id,
                model = agent, # The model we want to save
                hyperparameters = args,
                eval_env = gym.make(args.env_id),
                logs= f"runs/{run_name}",
                )

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# ## Let's start the training 🔥
# - ⚠️ ⚠️ ⚠️  Don't use **the same repo id with the one you used for the Unit 1**
# - Now that you've coded from scratch PPO and added the Hugging Face Integration, we're ready to start the training 🔥

# %% [markdown]
# - First, you need to copy all your code to a file you create called `ppo.py`

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/step1.png" alt="PPO"/>

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit9/step2.png" alt="PPO"/>

# %% [markdown]
# - Now we just need to run this python script using `python <name-of-python-script>.py` with the additional parameters we defined with `argparse`
#
# - You should modify more hyperparameters otherwise the training will not be super stable.

# %%
# !python ppo.py --env-id="LunarLander-v2" --repo-id="carlkaziboni/ppo-LunarLander-v2" --total-timesteps=50000
# Out:
# global_step=412, episodic_return=-255.037841796875
# global_step=420, episodic_return=-122.85197448730469
# global_step=468, episodic_return=-89.79412078857422
# SPS: 3477
# global_step=648, episodic_return=-263.0770263671875
# global_step=724, episodic_return=-59.831687927246094
# global_step=752, episodic_return=-25.898193359375
# global_step=780, episodic_return=-351.31939697265625
# SPS: 4643
# global_step=1056, episodic_return=-139.1411895751953
# global_step=1060, episodic_return=-128.04254150390625
# global_step=1084, episodic_return=-121.27458190917969
# global_step=1236, episodic_return=-319.7158203125
# global_step=1316, episodic_return=-375.51837158203125
# global_step=1408, episodic_return=-451.83905029296875
# global_step=1516, episodic_return=-331.7220764160156
# SPS: 5201
# global_step=1540, episodic_return=-112.8359375
# global_step=1652, episodic_return=43.03929138183594
# global_step=1764, episodic_return=-74.12971496582031
# global_step=1872, episodic_return=-143.17208862304688
# global_step=1956, episodic_return=-129.95921325683594
# global_step=1972, episodic_return=-107.01893615722656
# global_step=2040, episodic_return=-143.8880157470703
# SPS: 5592
# global_step=2252, episodic_return=-95.92797088623047
# global_step=2388, episodic_return=-135.60684204101562
# global_step=2416, episodic_return=-259.6710205078125
# global_step=2532, episodic_return=-159.01019287109375
# SPS: 5634
# global_step=2644, episodic_return=-136.67799377441406
# global_step=2664, episodic_return=-280.3209228515625
# global_step=2696, episodic_return=-85.39982604980469
# global_step=2976, episodic_return=-84.12346649169922
# SPS: 5794
# global_step=3088, episodic_return=-188.26405334472656
# global_step=3148, episodic_return=-185.3935546875
# global_step=3268, episodic_return=-100.9215087890625
# global_step=3384, episodic_return=-99.95025634765625
# global_step=3452, episodic_return=-147.1470947265625
# global_step=3492, episodic_return=-123.88790130615234
# global_step=3564, episodic_return=-209.79302978515625
# SPS: 5953
# global_step=3756, episodic_return=-173.46148681640625
# global_step=3788, episodic_return=-359.527587890625
# global_step=3856, episodic_return=-279.34783935546875
# global_step=3908, episodic_return=-121.62421417236328
# global_step=4044, episodic_return=-68.84230041503906
# SPS: 6090
# global_step=4140, episodic_return=-117.8783187866211
# global_step=4212, episodic_return=-124.28387451171875
# global_step=4220, episodic_return=-121.61280822753906
# global_step=4436, episodic_return=-144.40301513671875
# SPS: 6185
# global_step=4648, episodic_return=-116.67118072509766
# global_step=4668, episodic_return=-284.48773193359375
# global_step=4732, episodic_return=-86.57252502441406
# global_step=4928, episodic_return=-262.930419921875
# global_step=5096, episodic_return=-119.03085327148438
# SPS: 6256
# global_step=5132, episodic_return=-173.5597686767578
# global_step=5260, episodic_return=-115.39224243164062
# global_step=5400, episodic_return=-33.646148681640625
# global_step=5420, episodic_return=-99.52535247802734
# SPS: 6327
# global_step=5644, episodic_return=-315.37615966796875
# global_step=5648, episodic_return=-229.28379821777344
# global_step=5844, episodic_return=-435.63409423828125
# global_step=5876, episodic_return=-152.21817016601562
# global_step=6016, episodic_return=-160.63633728027344
# global_step=6088, episodic_return=-363.68798828125
# global_step=6112, episodic_return=-123.77804565429688
# SPS: 6349
# global_step=6200, episodic_return=-84.40078735351562
# global_step=6320, episodic_return=-47.22304153442383
# global_step=6500, episodic_return=-79.0847396850586
# global_step=6504, episodic_return=-278.43463134765625
# global_step=6532, episodic_return=-124.02255249023438
# SPS: 6358
# global_step=6680, episodic_return=-339.0491943359375
# global_step=6876, episodic_return=-114.83590698242188
# global_step=6896, episodic_return=-238.43707275390625
# global_step=6916, episodic_return=-100.74561309814453
# global_step=7064, episodic_return=-111.42485809326172
# SPS: 6389
# global_step=7188, episodic_return=-108.59732818603516
# global_step=7196, episodic_return=-182.60208129882812
# global_step=7464, episodic_return=-371.56170654296875
# global_step=7476, episodic_return=-79.3404541015625
# global_step=7520, episodic_return=-115.9981918334961
# global_step=7640, episodic_return=-170.07818603515625
# SPS: 6432
# global_step=7772, episodic_return=-61.99934768676758
# global_step=7916, episodic_return=-120.19154357910156
# global_step=7980, episodic_return=-219.8291015625
# global_step=8092, episodic_return=-134.5118408203125
# global_step=8104, episodic_return=-124.6221694946289
# SPS: 6464
# global_step=8340, episodic_return=-145.47567749023438
# global_step=8452, episodic_return=-141.936767578125
# global_step=8456, episodic_return=-150.82090759277344
# global_step=8472, episodic_return=-105.94624328613281
# global_step=8584, episodic_return=-106.59439849853516
# SPS: 6464
# global_step=8792, episodic_return=-184.06629943847656
# global_step=8872, episodic_return=-29.35199737548828
# global_step=8900, episodic_return=-331.9357604980469
# global_step=8964, episodic_return=-106.62249755859375
# global_step=9040, episodic_return=-130.69754028320312
# global_step=9196, episodic_return=-96.5189208984375
# SPS: 6382
# global_step=9376, episodic_return=-155.47451782226562
# global_step=9444, episodic_return=-159.44857788085938
# global_step=9464, episodic_return=-196.78506469726562
# global_step=9672, episodic_return=-381.7388916015625
# global_step=9684, episodic_return=-148.24655151367188
# SPS: 6354
# global_step=9852, episodic_return=-109.68428039550781
# global_step=9912, episodic_return=-130.19801330566406
# global_step=9984, episodic_return=-292.3990478515625
# global_step=10036, episodic_return=-118.95899963378906
# global_step=10104, episodic_return=-89.86796569824219
# SPS: 6375
# global_step=10344, episodic_return=-162.51931762695312
# global_step=10356, episodic_return=-18.220726013183594
# global_step=10428, episodic_return=-120.56053161621094
# global_step=10464, episodic_return=-84.90792846679688
# global_step=10680, episodic_return=-100.0270004272461
# SPS: 6391
# global_step=10804, episodic_return=-347.7535095214844
# global_step=10836, episodic_return=-164.00782775878906
# global_step=10980, episodic_return=-348.9726867675781
# global_step=11044, episodic_return=-182.43881225585938
# global_step=11260, episodic_return=-126.74652099609375
# SPS: 6377
# global_step=11308, episodic_return=-178.72259521484375
# global_step=11332, episodic_return=-147.38128662109375
# global_step=11392, episodic_return=-133.84072875976562
# global_step=11640, episodic_return=-120.48407745361328
# global_step=11692, episodic_return=-292.2937927246094
# global_step=11720, episodic_return=-201.01580810546875
# SPS: 6125
# global_step=11804, episodic_return=-103.32737731933594
# global_step=11948, episodic_return=-59.303470611572266
# global_step=11952, episodic_return=-63.508567810058594
# global_step=12156, episodic_return=-171.6862030029297
# global_step=12284, episodic_return=-92.07626342773438
# SPS: 6139
# global_step=12340, episodic_return=-179.89747619628906
# global_step=12376, episodic_return=-289.47540283203125
# global_step=12444, episodic_return=-118.61737823486328
# global_step=12568, episodic_return=-107.5336685180664
# global_step=12700, episodic_return=-113.29583740234375
# global_step=12740, episodic_return=-113.79447937011719
# global_step=12788, episodic_return=-224.1188201904297
# SPS: 6156
# global_step=13080, episodic_return=-129.9455108642578
# global_step=13140, episodic_return=-91.65657043457031
# global_step=13144, episodic_return=-76.02012634277344
# global_step=13188, episodic_return=-178.81585693359375
# SPS: 6166
# global_step=13424, episodic_return=-62.46478271484375
# global_step=13456, episodic_return=-129.50119018554688
# global_step=13464, episodic_return=-45.184600830078125
# global_step=13736, episodic_return=-66.0810546875
# global_step=13800, episodic_return=-314.35845947265625
# SPS: 6169
# global_step=13836, episodic_return=-97.17805480957031
# global_step=14020, episodic_return=-105.95480346679688
# global_step=14084, episodic_return=-321.5609436035156
# global_step=14140, episodic_return=-131.30392456054688
# global_step=14188, episodic_return=-88.4039077758789
# SPS: 6173
# global_step=14484, episodic_return=-250.02210998535156
# global_step=14520, episodic_return=-198.11184692382812
# global_step=14580, episodic_return=-161.6879425048828
# global_step=14600, episodic_return=-378.38616943359375
# global_step=14752, episodic_return=-113.12306213378906
# global_step=14792, episodic_return=-82.90406799316406
# SPS: 6180
# global_step=14956, episodic_return=-342.8795166015625
# global_step=14972, episodic_return=-305.68170166015625
# global_step=15052, episodic_return=-95.17273712158203
# global_step=15272, episodic_return=-226.05316162109375
# global_step=15300, episodic_return=-162.59307861328125
# SPS: 6180
# global_step=15448, episodic_return=-108.25238037109375
# global_step=15588, episodic_return=-89.38593292236328
# global_step=15732, episodic_return=-101.86942291259766
# global_step=15852, episodic_return=-3.5337448120117188
# SPS: 6168
# global_step=15896, episodic_return=-86.27094268798828
# global_step=15904, episodic_return=-193.37893676757812
# global_step=16044, episodic_return=-95.88758087158203
# global_step=16248, episodic_return=-118.09868621826172
# global_step=16280, episodic_return=-248.536865234375
# global_step=16328, episodic_return=-237.33941650390625
# SPS: 6182
# global_step=16420, episodic_return=-111.65653991699219
# global_step=16548, episodic_return=-80.10943603515625
# global_step=16624, episodic_return=-42.689151763916016
# global_step=16752, episodic_return=-293.72625732421875
# global_step=16832, episodic_return=-17.939659118652344
# SPS: 6168
# global_step=16900, episodic_return=-117.75729370117188
# global_step=16936, episodic_return=-105.81455993652344
# global_step=17084, episodic_return=-164.6839599609375
# global_step=17156, episodic_return=-108.2389144897461
# global_step=17180, episodic_return=-104.3274917602539
# global_step=17300, episodic_return=-183.8365020751953
# SPS: 6164
# global_step=17484, episodic_return=-334.968994140625
# global_step=17516, episodic_return=-56.31182861328125
# global_step=17596, episodic_return=-219.793701171875
# global_step=17620, episodic_return=-89.35450744628906
# global_step=17716, episodic_return=-79.60472106933594
# SPS: 6163
# global_step=18000, episodic_return=-85.38504791259766
# global_step=18104, episodic_return=-130.71925354003906
# global_step=18148, episodic_return=-226.94308471679688
# global_step=18268, episodic_return=-355.11822509765625
# SPS: 6154
# global_step=18556, episodic_return=-250.9130401611328
# global_step=18560, episodic_return=-155.40643310546875
# global_step=18584, episodic_return=-202.59877014160156
# global_step=18808, episodic_return=-64.87680053710938
# global_step=18896, episodic_return=-75.36758422851562
# SPS: 6151
# global_step=18984, episodic_return=-311.7491455078125
# global_step=19056, episodic_return=-74.563232421875
# global_step=19176, episodic_return=-60.359886169433594
# global_step=19196, episodic_return=-103.5145034790039
# global_step=19432, episodic_return=-218.21694946289062
# global_step=19452, episodic_return=-90.07527160644531
# SPS: 6168
# global_step=19520, episodic_return=-105.78406524658203
# global_step=19588, episodic_return=-35.465858459472656
# global_step=19736, episodic_return=-78.41250610351562
# global_step=19836, episodic_return=-49.98868942260742
# global_step=19940, episodic_return=-115.26072692871094
# global_step=19952, episodic_return=-99.94783020019531
# SPS: 6151
# global_step=20104, episodic_return=-132.88031005859375
# global_step=20308, episodic_return=-87.87692260742188
# global_step=20312, episodic_return=-104.04081726074219
# global_step=20436, episodic_return=-10.039443969726562
# SPS: 6156
# global_step=20656, episodic_return=-297.22491455078125
# global_step=20668, episodic_return=-151.09706115722656
# global_step=20724, episodic_return=-81.51979064941406
# global_step=20788, episodic_return=-167.51702880859375
# SPS: 6161
# global_step=21052, episodic_return=-101.17761993408203
# global_step=21076, episodic_return=-89.42036437988281
# global_step=21156, episodic_return=-147.65325927734375
# global_step=21212, episodic_return=-119.64688110351562
# global_step=21348, episodic_return=-83.36550903320312
# global_step=21356, episodic_return=-154.56387329101562
# global_step=21504, episodic_return=-82.12080383300781
# SPS: 6171
# global_step=21540, episodic_return=-132.41549682617188
# global_step=21592, episodic_return=-93.19779205322266
# global_step=21780, episodic_return=-178.21478271484375
# global_step=21832, episodic_return=-119.73660278320312
# global_step=21852, episodic_return=-118.06881713867188
# SPS: 6196
# global_step=22036, episodic_return=-144.48646545410156
# global_step=22068, episodic_return=-95.826904296875
# global_step=22120, episodic_return=-192.5999755859375
# global_step=22232, episodic_return=-172.14254760742188
# global_step=22476, episodic_return=-179.73817443847656
# global_step=22504, episodic_return=-340.89324951171875
# global_step=22512, episodic_return=-125.5926513671875
# SPS: 6211
# global_step=22564, episodic_return=-137.90879821777344
# global_step=22816, episodic_return=-100.64138793945312
# global_step=22848, episodic_return=-170.47994995117188
# global_step=22884, episodic_return=-104.77645874023438
# global_step=22908, episodic_return=-197.3788299560547
# SPS: 6225
# global_step=23112, episodic_return=-123.24594116210938
# global_step=23220, episodic_return=-351.31903076171875
# global_step=23292, episodic_return=-208.99398803710938
# global_step=23416, episodic_return=-95.07855987548828
# global_step=23440, episodic_return=-173.2791748046875
# SPS: 6226
# global_step=23584, episodic_return=-231.11309814453125
# global_step=23712, episodic_return=-113.54641723632812
# global_step=23736, episodic_return=-103.9561538696289
# global_step=23924, episodic_return=-167.3665771484375
# global_step=23956, episodic_return=-104.75
# global_step=24012, episodic_return=-151.46176147460938
# SPS: 6227
# global_step=24260, episodic_return=-211.93959045410156
# global_step=24264, episodic_return=-171.10952758789062
# global_step=24272, episodic_return=-161.1542510986328
# global_step=24316, episodic_return=-49.8817138671875
# global_step=24540, episodic_return=-77.90525817871094
# global_step=24552, episodic_return=-82.19683074951172
# SPS: 6236
# global_step=24644, episodic_return=-199.73023986816406
# global_step=24752, episodic_return=-100.5429458618164
# global_step=25000, episodic_return=-204.6064910888672
# global_step=25012, episodic_return=-81.00064086914062
# global_step=25044, episodic_return=-183.5540771484375
# global_step=25064, episodic_return=-77.59002685546875
# SPS: 6250
# global_step=25296, episodic_return=-126.9891128540039
# global_step=25312, episodic_return=-154.0370635986328
# global_step=25356, episodic_return=-81.98345947265625
# global_step=25596, episodic_return=-123.26932525634766
# SPS: 6272
# global_step=25704, episodic_return=-92.95279693603516
# global_step=25744, episodic_return=-125.31011962890625
# global_step=25748, episodic_return=-223.25128173828125
# global_step=26024, episodic_return=-85.3545913696289
# global_step=26100, episodic_return=-223.50506591796875
# global_step=26112, episodic_return=-110.86643981933594
# SPS: 6283
# global_step=26132, episodic_return=-138.22975158691406
# global_step=26360, episodic_return=-149.6922607421875
# global_step=26468, episodic_return=-333.19952392578125
# global_step=26476, episodic_return=-93.37036895751953
# SPS: 6301
# global_step=26644, episodic_return=-149.5115509033203
# global_step=26708, episodic_return=-108.839599609375
# global_step=26772, episodic_return=-49.46419906616211
# global_step=26964, episodic_return=-428.7795715332031
# global_step=26996, episodic_return=-109.57217407226562
# global_step=27064, episodic_return=-218.55587768554688
# SPS: 6310
# global_step=27184, episodic_return=-120.90618133544922
# global_step=27236, episodic_return=-96.67707824707031
# global_step=27456, episodic_return=-55.71310806274414
# global_step=27460, episodic_return=-194.80343627929688
# global_step=27576, episodic_return=-133.38629150390625
# SPS: 6280
# global_step=27696, episodic_return=-171.7390899658203
# global_step=27876, episodic_return=-149.23455810546875
# global_step=27932, episodic_return=-80.55499267578125
# global_step=27988, episodic_return=-284.41424560546875
# global_step=28040, episodic_return=-138.93409729003906
# SPS: 6294
# global_step=28228, episodic_return=-82.40461730957031
# global_step=28360, episodic_return=-5.552818298339844
# global_step=28432, episodic_return=-158.24322509765625
# global_step=28448, episodic_return=-165.0848388671875
# SPS: 6308
# global_step=28696, episodic_return=-317.27252197265625
# global_step=28772, episodic_return=-202.3321533203125
# global_step=28884, episodic_return=-242.56607055664062
# global_step=29072, episodic_return=-142.53280639648438
# global_step=29164, episodic_return=-267.79736328125
# SPS: 6312
# global_step=29200, episodic_return=-132.039306640625
# global_step=29272, episodic_return=-103.12268829345703
# global_step=29356, episodic_return=-73.017333984375
# global_step=29520, episodic_return=-60.1491813659668
# global_step=29528, episodic_return=-256.18634033203125
# SPS: 6327
# global_step=29708, episodic_return=-411.1448059082031
# global_step=29772, episodic_return=-59.38026809692383
# global_step=29796, episodic_return=-99.26045227050781
# global_step=29832, episodic_return=-79.21931457519531
# global_step=30036, episodic_return=-63.16164016723633
# global_step=30064, episodic_return=-86.25933837890625
# global_step=30152, episodic_return=-69.72991943359375
# SPS: 6343
# global_step=30224, episodic_return=-127.89411926269531
# global_step=30320, episodic_return=-42.54781723022461
# global_step=30472, episodic_return=-76.2830810546875
# global_step=30624, episodic_return=-191.28533935546875
# global_step=30704, episodic_return=-6.088134765625
# SPS: 6355
# global_step=30752, episodic_return=-176.65805053710938
# global_step=30900, episodic_return=-48.77601623535156
# global_step=31016, episodic_return=-96.77257537841797
# global_step=31020, episodic_return=-227.1296844482422
# global_step=31100, episodic_return=-254.86465454101562
# SPS: 6371
# global_step=31276, episodic_return=-188.95101928710938
# global_step=31336, episodic_return=-153.17828369140625
# global_step=31424, episodic_return=-176.69064331054688
# global_step=31468, episodic_return=-126.98529052734375
# global_step=31716, episodic_return=-100.79179382324219
# SPS: 6384
# global_step=31784, episodic_return=-103.43443298339844
# global_step=31792, episodic_return=-111.50819396972656
# global_step=31836, episodic_return=-100.48933410644531
# global_step=31996, episodic_return=-81.08998107910156
# global_step=32096, episodic_return=-82.54766082763672
# global_step=32188, episodic_return=-41.92329788208008
# global_step=32240, episodic_return=-241.25733947753906
# SPS: 6395
# global_step=32404, episodic_return=-124.02555847167969
# global_step=32452, episodic_return=-95.16160583496094
# global_step=32484, episodic_return=-104.76258087158203
# global_step=32652, episodic_return=-120.13961791992188
# global_step=32720, episodic_return=-115.9920883178711
# global_step=32768, episodic_return=-103.63401794433594
# SPS: 6407
# global_step=32916, episodic_return=-65.79776000976562
# global_step=32940, episodic_return=-274.2730712890625
# global_step=33140, episodic_return=-143.6337890625
# global_step=33180, episodic_return=-180.15475463867188
# SPS: 6419
# global_step=33380, episodic_return=-162.1403350830078
# global_step=33476, episodic_return=-130.5864715576172
# global_step=33544, episodic_return=-116.91512298583984
# global_step=33632, episodic_return=-162.2987060546875
# SPS: 6427
# global_step=33852, episodic_return=-103.94159698486328
# global_step=33900, episodic_return=-98.0989761352539
# global_step=33904, episodic_return=-131.1145782470703
# global_step=33972, episodic_return=-179.16482543945312
# global_step=34244, episodic_return=-105.12765502929688
# SPS: 6435
# global_step=34312, episodic_return=-107.37918090820312
# global_step=34376, episodic_return=-122.00819396972656
# global_step=34444, episodic_return=-140.4750213623047
# global_step=34604, episodic_return=-103.59361267089844
# global_step=34720, episodic_return=-316.74591064453125
# global_step=34788, episodic_return=-128.12904357910156
# SPS: 6445
# global_step=34908, episodic_return=-94.66471099853516
# global_step=34976, episodic_return=0.8469085693359375
# global_step=35248, episodic_return=-190.47787475585938
# global_step=35280, episodic_return=-105.07333374023438
# global_step=35324, episodic_return=-172.36276245117188
# SPS: 6449
# global_step=35392, episodic_return=-88.4327392578125
# global_step=35504, episodic_return=-134.6019744873047
# global_step=35696, episodic_return=-245.19549560546875
# global_step=35728, episodic_return=-69.4799575805664
# global_step=35744, episodic_return=-145.332763671875
# global_step=35816, episodic_return=-127.97248840332031
# SPS: 6462
# global_step=35988, episodic_return=-70.82799530029297
# global_step=36020, episodic_return=-90.4131851196289
# global_step=36096, episodic_return=-186.3489532470703
# global_step=36256, episodic_return=-406.0550842285156
# global_step=36312, episodic_return=-86.97016906738281
# global_step=36352, episodic_return=-114.10475158691406
# SPS: 6473
# global_step=36360, episodic_return=-105.74140930175781
# global_step=36548, episodic_return=-52.32350158691406
# global_step=36720, episodic_return=-210.0980682373047
# global_step=36744, episodic_return=-141.4114532470703
# global_step=36800, episodic_return=-108.4952163696289
# SPS: 6483
# global_step=36924, episodic_return=-105.70516204833984
# global_step=37012, episodic_return=-95.4547348022461
# global_step=37072, episodic_return=-99.41400909423828
# global_step=37084, episodic_return=-255.5206298828125
# global_step=37240, episodic_return=-109.67601776123047
# global_step=37364, episodic_return=-87.43407440185547
# SPS: 6495
# global_step=37388, episodic_return=-212.62063598632812
# global_step=37392, episodic_return=-124.24620056152344
# global_step=37636, episodic_return=-102.44510650634766
# global_step=37700, episodic_return=-146.20468139648438
# global_step=37704, episodic_return=-127.56639099121094
# global_step=37788, episodic_return=-118.45943450927734
# SPS: 6509
# global_step=37892, episodic_return=-86.02252197265625
# global_step=37996, episodic_return=-117.35576629638672
# global_step=38176, episodic_return=-202.45428466796875
# global_step=38248, episodic_return=-186.82301330566406
# global_step=38396, episodic_return=-221.16976928710938
# SPS: 6514
# global_step=38472, episodic_return=-15.117790222167969
# global_step=38520, episodic_return=-85.44020080566406
# global_step=38600, episodic_return=-191.40249633789062
# global_step=38868, episodic_return=-136.61024475097656
# SPS: 6520
# global_step=38956, episodic_return=-107.41361236572266
# global_step=38992, episodic_return=-147.77032470703125
# global_step=39024, episodic_return=-181.64088439941406
# global_step=39220, episodic_return=-77.248779296875
# global_step=39256, episodic_return=-58.221736907958984
# global_step=39272, episodic_return=-235.27117919921875
# SPS: 6529
# global_step=39496, episodic_return=-103.99469757080078
# global_step=39556, episodic_return=-97.09635162353516
# global_step=39636, episodic_return=-42.7746467590332
# global_step=39756, episodic_return=-133.6383819580078
# global_step=39872, episodic_return=-214.9158935546875
# SPS: 6535
# global_step=39980, episodic_return=-136.6473388671875
# global_step=40088, episodic_return=-125.54159545898438
# global_step=40108, episodic_return=-172.9964599609375
# global_step=40364, episodic_return=-166.18492126464844
# SPS: 6540
# global_step=40472, episodic_return=-150.65597534179688
# global_step=40512, episodic_return=-125.07461547851562
# global_step=40572, episodic_return=-94.09191131591797
# global_step=40656, episodic_return=-86.51249694824219
# global_step=40828, episodic_return=-132.70465087890625
# global_step=40840, episodic_return=-108.37046813964844
# global_step=40928, episodic_return=-185.14651489257812
# SPS: 6549
# global_step=41080, episodic_return=-142.61676025390625
# global_step=41168, episodic_return=-122.56398010253906
# global_step=41184, episodic_return=-86.21746063232422
# global_step=41232, episodic_return=-85.47071838378906
# global_step=41424, episodic_return=-101.33385467529297
# global_step=41448, episodic_return=-278.37762451171875
# SPS: 6558
# global_step=41584, episodic_return=-71.88264465332031
# global_step=41664, episodic_return=-115.73246002197266
# global_step=41780, episodic_return=-85.57896423339844
# global_step=41884, episodic_return=-185.37301635742188
# SPS: 6565
# global_step=42104, episodic_return=-110.9303207397461
# global_step=42124, episodic_return=-215.79959106445312
# global_step=42196, episodic_return=-181.6614990234375
# global_step=42312, episodic_return=-147.50430297851562
# global_step=42408, episodic_return=-26.71697998046875
# global_step=42492, episodic_return=-241.84262084960938
# SPS: 6571
# global_step=42572, episodic_return=-318.2015380859375
# global_step=42624, episodic_return=-116.39505767822266
# global_step=42780, episodic_return=-135.29049682617188
# global_step=42840, episodic_return=-197.73629760742188
# global_step=42976, episodic_return=-21.9791259765625
# SPS: 6577
# global_step=43096, episodic_return=-69.83374786376953
# global_step=43100, episodic_return=-326.13665771484375
# global_step=43172, episodic_return=-221.15338134765625
# global_step=43384, episodic_return=-111.93695068359375
# SPS: 6581
# global_step=43548, episodic_return=-39.83355712890625
# global_step=43556, episodic_return=-313.44439697265625
# global_step=43628, episodic_return=24.912994384765625
# global_step=43652, episodic_return=-91.64544677734375
# global_step=43856, episodic_return=-134.10061645507812
# global_step=43904, episodic_return=-55.55781555175781
# global_step=43964, episodic_return=-47.26152038574219
# SPS: 6588
# global_step=44068, episodic_return=-289.58734130859375
# global_step=44180, episodic_return=-124.92936706542969
# global_step=44312, episodic_return=-75.94220733642578
# global_step=44384, episodic_return=-224.57839965820312
# global_step=44476, episodic_return=-113.4389877319336
# global_step=44504, episodic_return=-59.8903923034668
# SPS: 6593
# global_step=44572, episodic_return=-88.20340728759766
# global_step=44860, episodic_return=-178.22381591796875
# global_step=44872, episodic_return=-130.48963928222656
# global_step=44948, episodic_return=-100.78227996826172
# global_step=45044, episodic_return=-311.22479248046875
# SPS: 6598
# global_step=45136, episodic_return=-84.74441528320312
# global_step=45200, episodic_return=-98.0983657836914
# global_step=45204, episodic_return=-126.59798431396484
# global_step=45372, episodic_return=-129.43875122070312
# global_step=45444, episodic_return=-40.259559631347656
# SPS: 6579
# global_step=45728, episodic_return=-41.12036895751953
# global_step=45736, episodic_return=-200.15512084960938
# global_step=45740, episodic_return=-282.9752197265625
# global_step=45816, episodic_return=-150.73272705078125
# global_step=46044, episodic_return=-187.85287475585938
# SPS: 6583
# global_step=46112, episodic_return=-96.04857635498047
# global_step=46200, episodic_return=4.23614501953125
# global_step=46356, episodic_return=-27.683921813964844
# global_step=46536, episodic_return=-146.12936401367188
# SPS: 6583
# global_step=46596, episodic_return=-78.91075897216797
# global_step=46648, episodic_return=-134.5550994873047
# global_step=46652, episodic_return=-198.48379516601562
# global_step=46872, episodic_return=-93.15746307373047
# global_step=46900, episodic_return=-92.48017120361328
# global_step=47036, episodic_return=-131.0369110107422
# global_step=47056, episodic_return=-204.65054321289062
# SPS: 6582
# global_step=47196, episodic_return=-120.41017150878906
# global_step=47336, episodic_return=-73.00849914550781
# global_step=47360, episodic_return=-112.17552185058594
# global_step=47452, episodic_return=-110.75940704345703
# global_step=47488, episodic_return=-149.18798828125
# global_step=47608, episodic_return=-100.44010925292969
# SPS: 6589
# global_step=47724, episodic_return=-162.44985961914062
# global_step=47912, episodic_return=-167.67872619628906
# global_step=47924, episodic_return=-134.66043090820312
# global_step=47940, episodic_return=-184.60693359375
# SPS: 6594
# global_step=48132, episodic_return=-99.478271484375
# global_step=48184, episodic_return=-83.08472442626953
# global_step=48228, episodic_return=-85.46347045898438
# global_step=48428, episodic_return=-171.41513061523438
# global_step=48452, episodic_return=-117.35794067382812
# global_step=48588, episodic_return=-234.60264587402344
# SPS: 6600
# global_step=48648, episodic_return=-143.9635467529297
# global_step=48892, episodic_return=-123.49908447265625
# global_step=48908, episodic_return=-198.71389770507812
# global_step=49008, episodic_return=-162.43605041503906
# global_step=49140, episodic_return=-130.1285858154297
# SPS: 6604
# global_step=49252, episodic_return=-105.00263977050781
# global_step=49296, episodic_return=-171.57615661621094
# global_step=49344, episodic_return=-140.0381317138672
# global_step=49432, episodic_return=-94.43692779541016
# global_step=49588, episodic_return=-97.96309661865234
# global_step=49664, episodic_return=-107.45191955566406
# SPS: 6612
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ℹ Pushing repo carlkaziboni/ppo-LunarLander-v2 to the Hugging Face
# Hub
# Upload 3 LFS files:   0%|                                 | 0/3 [00:00<?, ?it/s]
# events.out.tfevents.1751143137.Carls-Air.81361.0:   0%| | 0.00/114k [00:00<?, ?B
#
# replay.mp4:   0%|                                   | 0.00/24.3k [00:00<?, ?B/s]
#
#
# replay.mp4: 100%|██████████████████████████| 24.3k/24.3k [00:00<00:00, 75.7kB/s]
# model.pt: 100%|████████████████████████████| 43.3k/43.3k [00:00<00:00, 87.0kB/s]
# events.out.tfevents.1751143137.Carls-Air.81361.0: 100%|█| 114k/114k [00:00<00:00
# Upload 3 LFS files: 100%|█████████████████████████| 3/3 [00:01<00:00,  2.21it/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/carlkaziboni/ppo-LunarLander-v2/tree/main/

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  another environment?

# %% [markdown]
# See you on Unit 8, part 2 where we going to train agents to play Doom 🔥
# ## Keep learning, stay awesome 🤗
